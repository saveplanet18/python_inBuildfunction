# %%
def Insertion_at_Start(arr,ele):
    n = len(arr)
    arr.append(None)
    for i in range(n-1,-1,-1):
        arr[i+1] = arr[i]
    arr[0] = ele
    return arr


if __name__ == "__main__":
    arr = [18,45,36]
    Insertion_at_Start(arr,108)
    Insertion_at_Start(arr,57)
    print(arr)
# Out:
# [57, 108, 18, 45, 36]

# %%
def Insertion_at_specific(arr,pos,ele):
    n = len(arr)
    arr.append(None)
    for i in range(n-1,pos-1,-1):
        arr[i+1] = arr[i]
    arr[pos] = ele
    return arr

if __name__ == "__main__":
    arr = [18,45,36]
    Insertion_at_specific(arr,2,108)
    Insertion_at_specific(arr,3,84)
    print(arr)
# Out:
# [18, 45, 108, 84, 36]

# %%
def Insertion_at_End(arr,ele):
    n = len(arr)
    arr.append(None)
    for i in range(n-1,-1):
        arr[i+1] = arr[i]
    arr[-1] = ele
    return arr


if __name__ == "__main__":
    arr = [18,45,36]
    Insertion_at_End(arr,89)
    Insertion_at_End(arr,90)
    print(arr)
# Out:
# [18, 45, 36, 89, 90]

# %%
class Insertion_Object(object):
    def __init__(self):
        self.Mylist = []

    def Insertion_at_Start(self,ele):
        n = len(self.Mylist)
        self.Mylist.append(None)
        for i in range(n-1,-1,-1):
            self.Mylist[i+1] = self.Mylist[i]
        self.Mylist[0] = ele
        return self.Mylist
    
    def Insertion_at_specific(self,pos,ele):
        n = len(self.Mylist)
        self.Mylist.append(None)
        if (pos < 1):
            print("position is should be greater than <= 1")
        elif (pos == 1):
            for i in range(n-1,-1,-1):
                self.Mylist[i+1] = self.Mylist[i]
            self.Mylist[0] = ele
            return
        else:
            for i in range(n-1,pos-1,-1):
                self.Mylist[i+1] = self.Mylist[i]
            self.Mylist[pos] = ele
            return self.Mylist
        
    def Insertion_at_End(self,ele):
        n = len(self.Mylist)
        self.Mylist.append(None)
        for i in range(n-1,-1):
            self.Mylist[i+1] = self.Mylist[i]
        self.Mylist[-1] = ele
        return self.Mylist
    
    def Traverser_Linked_List(self):
        temp = self.Mylist
        for i in range(len(temp)):
            print(temp[i],end = '->')



if __name__ == "__main__":
    root = Insertion_Object()
    root.Insertion_at_Start(45)
    root.Insertion_at_Start(36)
    root.Insertion_at_Start(18)
    root.Insertion_at_specific(2,58)
    root.Insertion_at_specific(1,78)
    root.Insertion_at_specific(3,58)
    root.Insertion_at_End(87)
    root.Insertion_at_End(25)
    root.Insertion_at_End(41)
    root.Traverser_Linked_List()
# Out:
# 78->18->36->58->58->45->87->25->41->

# %%
class Singly_Linked_Creation(object):
    def __init__(self,elements):
        self.elements = elements
        self.Next = None

    
class Singly_Linked_List():
    def __init__(self):
        self.Head = None

    def Insertion_at_Start(self,ele):
        new_object = Singly_Linked_Creation(ele)
        if (self.Head == None):
            self.Head = new_object
            return
        else:
            new_object.Next = self.Head
            self.Head = new_object

    def Insertion_at_specific(self,pos,ele):
        new_object = Singly_Linked_Creation(ele)
        if (pos < 1):
            print("position is greater than <= 1")
        elif (pos == 1 and self.Head == None):
            self.Head = new_object
            new_object.Next = self.Head
            return
        else:
            temp = self.Head
            for i in range(pos-1):
                if (temp.Next != None):
                    temp = temp.Next
            if (temp != None):
                new_object.Next = temp.Next
                temp.Next = new_object

    def Insertion_at_End(self,ele):
        new_Object = Singly_Linked_Creation(ele)
        if (self.Head == None):
            self.Head = new_Object
            new_Object.Next = self.Head
            return
        else:
            temp = self.Head
            while (temp.Next != None):
                temp = temp.Next
            temp.Next = new_Object

    def Deletion_at_Start(self):
        if (self.Head == None):
            self.Head = None
            return
        else:
            First_Node = None
            self.Head = self.Head.Next
            First_Node = None

    def Deletion_at_specific(self,pos):
        if (pos < 1):
            print("position is greater than <= 1")
        elif (pos == 1 and self.Head == None):
            First_Node = None
            self.Head = self.Head.Next
            First_Node = None
        else:
            temp = self.Head
            for i in range(pos-1):
                if (temp != None):
                    temp = temp.Next
            if (temp != None):
                position_Node = temp.Next
                temp.Next = temp.Next.Next
                position_Node = None
    def Search_Node(self,item):
        temp = self.Head
        i = 0
        found = 0
        if (temp != None):
            while (temp != None):
                i += 1
                if (temp.elements == item):
                    found += 1
                    break
                temp = temp.Next
            if (found == 1):
                print(found,"elements are found",i)
            else:
                print(found,"elements are not found",i)
    def Count_ALL_(self):
        temp = self.Head
        Count = 0
        while (temp.Next != None):
            Count += 1
            temp = temp.Next
        return Count
    
    def Deletion_at_End(self):
        if (self.Head == None):
            First_Node = self.Head
            self.Head = self.Head.Next
            First_Node = None
            return
        else:
            temp = self.Head
            while (temp.Next.Next != None):
                temp = temp.Next
            End_Node = temp.Next
            temp.Next = temp.Next.Next
            End_Node = None

    def Traverser_Linked_List(self):
        temp = self.Head
        if (temp != None):
            print("elements are listed..")
            while(temp != None):
                print(temp.elements , end = '->')
                temp = temp.Next
            print()
        else:
            print("elements are empty")

if __name__ == "__main__":
    root = Singly_Linked_List()
    root.Insertion_at_Start(45)
    root.Insertion_at_Start(36)
    root.Insertion_at_Start(18)
    root.Insertion_at_specific(2,89)
    root.Insertion_at_specific(1,58)
    root.Insertion_at_specific(3,84)
    root.Insertion_at_End(89)
    root.Insertion_at_End(58)
    root.Insertion_at_End(74)
    root.Search_Node(89)
    print(root.Count_ALL_())
    root.Deletion_at_Start()
    root.Deletion_at_Start()
    root.Deletion_at_Start()
    root.Deletion_at_specific(2)
    root.Deletion_at_specific(1)
    root.Deletion_at_specific(3)
    root.Deletion_at_End()
    root.Deletion_at_End()
    root.Traverser_Linked_List()
# Out:
# 1 elements are found 5
# 8
# elements are listed..
# 84->

# %%
class Singly_Linked_Creation_Circular(object):
    def __init__(self,elements):
        self.elements = elements
        self.Next = None


class Singly_Linked_List_Circular():
    def __init__(self):
        self.Head = None
    
    def Insertion_at_Start(self,ele):
        new_Object = Singly_Linked_Creation_Circular(ele)
        if (self.Head == None):
            self.Head = new_Object
            new_Object.Next = self.Head
            return
        else:
            temp = self.Head
            while (temp.Next != self.Head):
                temp = temp.Next
            temp.Next = new_Object
            new_Object.Next = self.Head
            self.Head = new_Object
            
    def Insertion_at_specific(self,pos,ele):
        new_Object = Singly_Linked_Creation_Circular(ele)
        if (pos < 1):
            print("position is greater than <= 1")
        elif (pos == 1 and self.Head.Next == self.Head):
            self.Head = new_Object
            new_Object.Next = self.Head
            self.Head = new_Object
            return
        else:
            temp = self.Head
            for i in range(pos-1):
                if (temp.Next != self.Head):
                    temp = temp.Next
            if (temp != None):
                new_Object.Next = temp.Next
                temp.Next = new_Object

    def Insertion_at_End(self,ele):
        new_Object = Singly_Linked_Creation_Circular(ele)
        if (self.Head == None):
            self.Head = new_Object
            new_Object.Next = self.Head
            self.Head = new_Object
            return
        else:
            temp = self.Head
            while (temp.Next != self.Head):
                temp = temp.Next
            temp.Next = new_Object
            new_Object.Next = self.Head

    def Search_Node(self,item):
        temp = self.Head
        i = 0
        found = 0
        if (temp != None):
            # print("elements are found")
            while (temp != None):
                i += 1
                if (temp.elements == item):
                    found += 1
                    break
                temp = temp.Next
            if (found == 1):
                print(found,"elements are found",i)
            else:
                print(found,"elements are not found",i)

        #         print(temp.elements , end = '->')
        #         temp = temp.Next
        #     print()
        # else:
        #     print("elements are empty")
    def Count_All(self):
        temp = self.Head
        Count = 0
        while (temp.Next != self.Head):
            Count += 1
            temp = temp.Next
        return Count
    
    def Deletion_at_Start(self):
        if (self.Head == None):
            self.Head = None
            return
        else:
            temp = self.Head
            while (temp.Next != self.Head):
                temp = temp.Next
            First_Node = temp.Next
            self.Head = self.Head.Next
            temp.Next = self.Head
            First_Node = None

    def Deletion_at_Specific(self,pos):
        if (pos < 1):
            print("position is greater than <= 1")
        elif (pos == 1 and self.Head.Next == self.Head):
            First_Node = self.Head
            self.Head = self.Head.Next
            First_Node = None
            return
        else:
            temp = self.Head
            for i in range(pos-1):
                if (temp.Next != self.Head):
                    temp = temp.Next
            if (temp != None):
                Position = temp.Next
                temp.Next = temp.Next.Next
                Position = None

    def Deletion_at_End(self):
        if (self.Head == None):
            self.Head = None
        else:
            temp = self.Head
            while (temp.Next.Next != self.Head):
                temp = temp.Next
            End_Node = temp.Next
            temp.Next = temp.Next.Next
            End_Node = None

    def Traverser_Linked_List_Circular(self):
        temp = self.Head
        if (temp != None):
            print("elements are listed..")
            while (temp != None):
                print(temp.elements , end ='->')
                temp = temp.Next
                if (temp == self.Head):
                    break
            print()
        else:
            print('elements are empty')

if __name__ == "__main__":
    root = Singly_Linked_List_Circular()
    root.Insertion_at_Start(45)
    root.Insertion_at_Start(36)
    root.Insertion_at_Start(18)
    root.Insertion_at_specific(2,89)
    root.Insertion_at_specific(1,69)
    root.Insertion_at_specific(3,79)
    root.Insertion_at_End(87)
    root.Insertion_at_End(58)
    root.Insertion_at_End(74)
    root.Search_Node(89)
    print(root.Count_All())
    root.Deletion_at_Start()
    root.Deletion_at_Start()
    root.Deletion_at_Start()
    root.Deletion_at_Specific(1)
    root.Deletion_at_Specific(2)
    root.Deletion_at_Specific(3)
    root.Deletion_at_End()
    root.Deletion_at_End()
    root.Traverser_Linked_List_Circular()
# Out:
# 1 elements are found 5
# 8
# elements are listed..
# 79->

# %%
class Doubly_Creation_Node(object):
    def __init__(self,elements):
        self.elements = elements
        self.Next = None
        self.Prev = None


class Doubly_Linked_List():
    def __init__(self):
        self.Head = None


    def Insertion_at_Start(self,ele):
        new_Object = Doubly_Creation_Node(ele)
        if (self.Head == None):
            self.Head = new_Object
            return
        else:
            self.Head.Prev = new_Object
            new_Object.Next = self.Head
            self.Head = new_Object
    def Insertion_at_specific(self,pos,ele):
        new_Object = Doubly_Creation_Node(ele)
        if (pos < 1):
            print("position is greater than <= 1")
        elif (pos == 1 and self.Head.Next == self.Head):
            self.Head.Prev = new_Object
            new_Object.Next = self.Head
            self.Head = new_Object
            return
        else:
            temp = self.Head
            for i in range(pos-1):
                if (temp.Next != None):
                    temp = temp.Next
            if (temp != None):
                new_Object.Next = temp.Next
                temp.Next = new_Object
                new_Object.Prev = self.Head
    def Search_Node(self,item):
        temp = self.Head
        i = 0
        found = 0
        if (temp != None):
            while (temp != None):
                i += 1
                if (temp.elements == item):
                    found += 1
                    break
                temp = temp.Next
            if (found == 1):
                print(found,'elements are found',i)
            else:
                print(found,'elements are not foudn',i)

    def Insertion_at_End(self,ele):
        new_Object = Doubly_Creation_Node(ele)
        if (self.Head == None):
            self.Head = new_Object
            new_Object.Next = self.Head
            self.Head.Prev = new_Object
            return
        else:
            temp = self.Head
            while (temp.Next != None):
                temp = temp.Next
            temp.Next = new_Object
            new_Object.Prev = self.Head

    def Count_All(self):
        temp = self.Head
        Count = 0
        while (temp.Next != None):
            Count += 1
            temp = temp.Next
        return Count
    
    def Deletion_at_Start(self):
        if (self.Head == None):
            self.Head = None
            return
        else:
            First_Node = self.Head
            self.Head = self.Head.Next
            First_Node.Prev = None

    def Deletion_at_Position(self,pos):
        if(pos < 1):
            print("position is greater than <= 1")
        elif (pos == 1 and self.Head.Next == None):
            First_Node = self.Head
            self.Head = self.Head.Next
            First_Node.Prev = None
            return
        else:
            temp = self.Head
            for i in range(pos-1):
                if (temp.Next.Next != None):
                    temp = temp.Next
            if (temp != None):
                Position_Node = temp.Next
                temp.Next = temp.Next.Next
                Position_Node.Prev = None

    def Deletion_at_End(self):
        if (self.Head == None):
            First_Node = self.Head
            self.Head = self.Head.Next
            First_Node.Prev = None
            return
        else:
            temp = self.Head
            while (temp.Next.Next != None):
                temp = temp.Next
            End_Node = temp.Next
            temp.Next = temp.Next.Next
            End_Node = None
    
    def Traverse_Linked_List(self):
        temp = self.Head
        if (temp != None):
            print("elements are listed..")
            while (temp != None):
                print(temp.elements , end = '->')
                temp = temp.Next
            print()
        else:
            print("elements are empty")


if __name__ == "__main__":
    root = Doubly_Linked_List()
    root.Insertion_at_Start(45)
    root.Insertion_at_Start(36)
    root.Insertion_at_Start(18)
    root.Insertion_at_specific(1,89)
    root.Insertion_at_specific(2,87)
    root.Insertion_at_specific(3,58)
    root.Insertion_at_End(69)
    root.Insertion_at_End(56)
    root.Insertion_at_End(57)
    root.Search_Node(87)
    print(root.Count_All())
    root.Deletion_at_Start()
    root.Deletion_at_Start()
    root.Deletion_at_Position(1)
    root.Deletion_at_Position(2)
    root.Deletion_at_Position(3)
    root.Deletion_at_End()
    root.Deletion_at_End()
    root.Deletion_at_End()
    root.Traverse_Linked_List()
# Out:
# 1 elements are found 3
# 8
# elements are listed..
# 87->

# %%
class Doubly_Creation_Node_Circular(object):
    def __init__(self,elements):
        self.elements = elements
        self.Next = None
        self.Prev = None


class Doubly_Linked_List_Circular():
    def __init__(self):
        self.Head = None

    def Insertion_at_Start(self,ele):
        new_Object = Doubly_Creation_Node_Circular(ele)
        if (self.Head == None):
            self.Head = new_Object
            new_Object.Next = self.Head
            self.Head.Prev = new_Object
            return
        else:
            temp = self.Head
            while (temp.Next != self.Head):
                temp = temp.Next
            temp.Next = new_Object
            new_Object.Prev = temp
            new_Object.Next = self.Head
            self.Head = new_Object
    def Insertion_at_specific(self,pos,ele):
        new_Object = Doubly_Creation_Node_Circular(ele)
        if (pos < 1 ):
            print("position is greater than <= 1")
        elif (pos == 1 and self.Head.Next == self.Head):
            self.Head = new_Object
            new_Object.Next = self.Head
            new_Object.Prev = self.Head
            self.Head = new_Object
            return
        else:
            temp = self.Head
            for i in range(pos-1):
                if (temp.Next != self.Head):
                    temp = temp.Next
            if (temp != None):
                new_Object.Next = temp.Next
                temp.Next = new_Object
                new_Object.Prev = temp
    def Insertion_at_End(self,ele):
        new_Object = Doubly_Creation_Node_Circular(ele)
        if (self.Head == None):
            self.Head = new_Object
            new_Object.Next = self.Head
            self.Head.Prev = new_Object
            return
        else:
            temp = self.Head
            while (temp.Next != self.Head):
                temp = temp.Next
            temp.Next = new_Object
            new_Object.Next = self.Head
            self.Head.Prev = new_Object
    
    def Deletion_at_Start(self):
        if (self.Head == None):
            self.Head = None
            return
        else:
            temp = self.Head
            while (temp.Next != self.Head):
                temp = temp.Next
            First_Node = temp.Next
            self.Head = self.Head.Next
            temp.Next = self.Head
            First_Node = None
    def Deletion_at_specific(self,pos):
        if (pos < 1):
            print("position is greater than <= 1")
        elif (pos == 1 and self.Head.Next == self.Head):
            First_Node = self.Head
            self.Head = self.Head.Next
            First_Node = None
            return
        else:
            temp = self.Head
            for i in range(pos-1):
                if (temp.Next != self.Head):
                    temp = temp.Next
            if (temp != None):
                Position = temp.Next
                temp.Next = temp.Next.Next
                Position = None
    def Deletion_at_End(self):
        if (self.Head == None):
            First_Node = self.Head
            self.Head = self.Head.Next
            First_Node = None
            return
        else:
            temp = self.Head
            while (temp.Next.Next != self.Head):
                temp = temp.Next
            End_Node = temp.Next
            temp.Next = temp.Next.Next
            temp.Next = self.Head
            End_Node.Prev = None

    def Traverser_Linked_List(self):
        temp = self.Head
        if (temp != None):
            print("elements are listed...")
            while (temp != None):
                print(temp.elements , end ='->')
                temp = temp.Next
                if (temp == self.Head):
                    break
            print()
        else:
            print("elements are empty..")


if __name__ == "__main__":
    root = Doubly_Linked_List_Circular()
    root.Insertion_at_Start(45)
    root.Insertion_at_Start(36)
    root.Insertion_at_Start(18)
    root.Insertion_at_specific(2,89)
    root.Insertion_at_specific(1,87)
    root.Insertion_at_specific(3,88)
    root.Insertion_at_End(89)
    root.Insertion_at_End(90)
    root.Insertion_at_End(99)
    root.Deletion_at_Start()
    root.Deletion_at_Start()
    root.Deletion_at_specific(1)
    root.Deletion_at_specific(2)
    root.Deletion_at_specific(3)
    root.Deletion_at_End()
    root.Deletion_at_End()
    root.Deletion_at_End()
    root.Traverser_Linked_List()
# Out:
# elements are listed...
# 36->

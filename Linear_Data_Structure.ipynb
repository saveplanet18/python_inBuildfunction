# %%
def Insertion_at_Start(arr,ele):
    n = len(arr)
    arr.append(None)
    for i in range(n-1,-1,-1):
        arr[i+1] = arr[i]
    arr[0] = ele
    return arr

if __name__ == "__main__":
    arr = [18,35,45]
    Insertion_at_Start(arr,81)
    print(arr)
# Out:
# [81, 18, 35, 45]

# %%
def Inserton_at_Specific(arr,pos,ele):
    n = len(arr)
    arr.append(None)
    if (pos < 1):
        print("position is greater than <= 1")
    elif (pos == 1):
        for i in range(n-1,-1,-1):
            arr[i+1] = arr[i]
        arr[0] = ele
        return arr
    else:
        for i in range(n-1,pos-1,-1):
            arr[i+1] = arr[i]
        arr[pos] = ele
        return arr
    
if __name__ == "__main__":
    arr = [18,35,45]
    Inserton_at_Specific(arr,2,81)
    Inserton_at_Specific(arr,3,57)
    print(arr)
# Out:
# [18, 35, 81, 57, 45]

# %%
def Insertion_at_End(arr,ele):
    n = len(arr)
    arr.append(None)
    for i in range(n-1,-1):
        arr[i+1] = arr[i]
    arr[-1] = ele
    return arr

if __name__ == "__main__":
    arr = [18,35,45]
    Insertion_at_End(arr,64)
    Insertion_at_End(arr,85)
    print(arr)
# Out:
# [18, 35, 45, 64, 85]

# %%
class Insertion_at_Object(object):
    def __init__(self):
        self.MyList = []
    
    def Insertion_at_Start(self,ele):
        n = len(self.MyList)
        self.MyList.append(None)
        for i in range(n-1,-1,-1):
            self.MyList[i+1] = self.MyList[i]
        self.MyList[0] = ele
        return self.MyList
    
    def Inserton_at_Specific(self,pos,ele):
        n = len(self.MyList)
        self.MyList.append(None)
        if (pos < 1):
            print("position is greater than <= 1")
        elif (pos == 1):
            for i in range(n-1,-1,-1):
                self.MyList[i+1] = self.MyList[i]
            self.MyList[0] = ele
            return self.MyList
        else:
            for i in range(n-1,pos-1,-1):
                self.MyList[i+1] = self.MyList[i]
            self.MyList[pos] = ele
            return self.MyList
        
    def Insertion_at_End(self,ele):
        n = len(self.MyList)
        self.MyList.append(None)
        for i in range(n-1,-1):
            self.MyList[i+1] = self.MyList[i]
        self.MyList[-1] = ele
        return self.MyList
    
    def Traversed_Insertion_at_Object(self):
        temp = self.MyList
        for i in range(len(temp)):
            print(temp[i], end ='->')



if __name__ == "__main__":
    root = Insertion_at_Object()
    root.Insertion_at_Start(18)
    root.Insertion_at_Start(36)
    root.Insertion_at_Start(45)
    root.Inserton_at_Specific(2,89)
    root.Inserton_at_Specific(3,90)
    root.Inserton_at_Specific(1,81)
    root.Insertion_at_End(98)
    root.Insertion_at_End(99)
    root.Insertion_at_End(96)
    root.Traversed_Insertion_at_Object()
# Out:
# 81->45->36->89->90->18->98->99->96->

# %%
class Singly_Creation_Node(object):
    def __init__(self,elements):
        self.elements = elements
        self.Next = None


class Singly_Linked_List(object):
    def __init__(self):
        self.Head = None

    def Insertion_at_Start(self,ele):
        new_Object = Singly_Creation_Node(ele)
        if (self.Head == None):
            self.Head = new_Object
            return
        else:
            new_Object.Next = self.Head
            self.Head = new_Object

    def Inserton_at_Specific(self,pos,ele):
        new_Object = Singly_Creation_Node(ele)
        if (pos < 1):
            print("position is greater than <= 1")
        elif (pos == 1 and self.Head == None):
            self.Head = new_Object
            new_Object.Next = self.Head
            return 
        else:
            temp = self.Head
            for i in range(pos-1):
                if (temp.Next != None):
                    temp = temp.Next
            if (temp != None):
                new_Object.Next = temp.Next
                temp.Next = new_Object

    def Insertion_at_End(self,ele):
        new_Object = Singly_Creation_Node(ele)
        if (self.Head == None):
            self.Head = new_Object
            new_Object.Next = self.Head
            return 
        else:
            temp = self.Head
            while (temp.Next != None):
                temp = temp.Next
            temp.Next = new_Object

    def Search_Node(self,item):
        temp = self.Head
        found = 0
        i = 0
        if (temp != None):
            while (temp != None):
                i += 1
                if (temp.elements == item):
                    found += 1
                    break
                temp = temp.Next
            if (found == 1):
                print(found,"elements are found",i)
            else:
                print(found,'elements are not found',i)
        else:
            print("elements are empty")
    
    def Count_Node(self):
        temp = self.Head
        Count = 0
        while (temp != None):
            Count += 1
            temp = temp.Next
        return Count
    
    def Deletion_at_Start(self):
        if (self.Head == None):
            self.Head = None
            return
        else:
            First_Node = self.Head
            self.Head = self.Head.Next
            First_Node = None

    def Deletion_at_specific(self,pos):
        if (pos < 1):
            print("position is greater than <= 1")
        elif (pos == 1 and self.Head == None):
            First_Node = self.Head
            self.Head = self.Head.Next
            First_Node = None
            return
        else:
            temp = self.Head
            for i in range(pos-1):
                if (temp.Next != None):
                    temp = temp.Next
            if (temp != None):
                Position_Node = temp.Next
                temp.Next = temp.Next.Next
                Position_Node = None

    def Deletion_at_End(self):
        if (self.Head == None):
            First_Node = self.Head
            self.Head = self.Head.Next
            First_Node = None
            return
        else:
            temp = self.Head
            while (temp.Next.Next != None):
                temp = temp.Next
            Last_Node = temp.Next
            temp.Next = temp.Next.Next
            Last_Node = None
    
    def Traverser_Linked_List(self):
        temp = self.Head
        if (temp != None):
            print("elements are listed...")
            while (temp != None):
                print(temp.elements , end ='->')
                temp = temp.Next
            print()
        else:
            print("elements are empty...")


if __name__ == "__main__":
    root = Singly_Linked_List()
    root.Insertion_at_Start(45)
    root.Insertion_at_Start(36)
    root.Insertion_at_Start(18)
    root.Inserton_at_Specific(2,89)
    root.Inserton_at_Specific(1,90)
    root.Inserton_at_Specific(3,85)
    root.Insertion_at_End(24)
    root.Insertion_at_End(32)
    root.Insertion_at_End(41)
    root.Search_Node(90)
    print(root.Count_Node())
    root.Deletion_at_Start()
    root.Deletion_at_Start()
    root.Deletion_at_Start()
    root.Deletion_at_specific(1)
    root.Deletion_at_specific(2)
    root.Deletion_at_specific(3)
    root.Deletion_at_End()
    root.Deletion_at_End()
    root.Traverser_Linked_List()
# Out:
# 1 elements are found 2
# 9
# elements are listed...
# 85->

# %%
class Singly_Circular_Creation_Node(object):
    def __init__(self,elements):
        self.elements = elements
        self.Next = None

class Singly_Circular_Linked_List():
    def __init__(self):
        self.Head = None

    def Insertion_at_Start(self,ele):
        new_Object = Singly_Circular_Creation_Node(ele)
        if (self.Head == None):
            self.Head = new_Object
            new_Object.Next = self.Head
            return
        else:
            temp = self.Head
            while (temp.Next != self.Head):
                temp = temp.Next
            temp.Next = new_Object
            new_Object.Next = self.Head
            self.Head = new_Object
    
    def Inserton_at_Specific(self,pos,ele):
        new_Object = Singly_Circular_Creation_Node(ele)
        if (pos < 1):
            print("position is greater than <= 1")
        elif (pos == 1 and self.Head == None):
            self.Head = new_Object
            new_Object.Next = self.Head
            self.Head = new_Object
            return
        else:
            temp = self.Head
            for i in range(pos-1):
                if (temp.Next != self.Head):
                    temp = temp.Next
            if (temp != None):
                new_Object.Next = temp.Next
                temp.Next = new_Object

    def Insertion_at_End(self,ele):
        new_Object = Singly_Circular_Creation_Node(ele)
        if (self.Head == None):
            self.Head = new_Object
            new_Object.Next = self.Head
            self.Head = new_Object
            return
        else:
            temp = self.Head
            while (temp.Next != self.Head):
                temp = temp.Next
            temp.Next = new_Object
            new_Object.Next = self.Head

    def Search_Node(self,item):
        temp = self.Head
        found = 0
        i = 0
        if (temp != None):
            while (temp != None):
                i += 1
                if (temp.elements == item):
                    found += 1
                    break
                temp = temp.Next
            if (found == 1):
                print(found,"elements is found" ,i)
            else:
                print(found,"elements is not found",i)
        else:
            print("elements are not empty")
    
    def Count_Node(self):
        temp = self.Head
        Count = 0
        while (temp.Next != self.Head):
            Count += 1
            temp = temp.Next
        return Count
    
    def Deletion_at_Start(self):
        if (self.Head == None):
            self.Head = None
            return
        else:
            temp = self.Head
            while (temp.Next != self.Head):
                temp = temp.Next
            First_Node = temp.Next
            self.Head = self.Head.Next
            temp.Next = self.Head
            First_Node = None

    def Deletion_at_Specific(self,pos):
        if (pos < 1):
            print("position is greater than <= 1")
        elif (pos == 1 and self.Head == None):
            First_Node = self.Head
            self.Head = self.Head.Next
            First_Node = None
            return
        else:
            temp = self.Head
            for i in range(pos-1):
                if (temp.Next != self.Head):
                    temp = temp.Next
            if (temp != None):
                Postion_Node = temp.Next
                temp.Next = temp.Next.Next
                Postion_Node = None

    def Deletion_at_End(self):
        if (self.Head == None):
            First_Node = self.Head
            self.Head = self.Head.Next
            First_Node = None
            return
        else:
            temp = self.Head
            while (temp.Next.Next != self.Head):
                temp = temp.Next
            Last_Node = temp.Next
            temp.Next = temp.Next.Next
            self.Head = temp.Next
            Last_Node = None

    def Traverser_Circular_List(self):
        temp = self.Head
        if (temp != None):
            print("elements are listed...")
            while (temp != None):
                print(temp.elements , end ='->')
                temp = temp.Next
                if (temp == self.Head):
                    break
            print()
        else:
            print("elements are Empty")


if __name__ == "__main__":
    root = Singly_Circular_Linked_List()
    root.Insertion_at_Start(45)
    root.Insertion_at_Start(36)
    root.Insertion_at_Start(18)
    root.Inserton_at_Specific(2,89)
    root.Inserton_at_Specific(3,86)
    root.Inserton_at_Specific(1,88)
    root.Insertion_at_End(90)
    root.Insertion_at_End(91)
    root.Insertion_at_End(92)
    root.Search_Node(89)
    print(root.Count_Node())
    root.Deletion_at_Start()
    root.Deletion_at_Start()
    root.Deletion_at_Start()
    root.Deletion_at_Specific(2)
    root.Deletion_at_Specific(1)
    root.Deletion_at_Specific(3)
    root.Deletion_at_End()
    root.Deletion_at_End()
    root.Traverser_Circular_List()
# Out:
# 1 elements is found 4
# 8
# elements are listed...
# 89->

# %%
class Doubly_Creation_Node(object):
    def __init__(self,elements):
        self.elements = elements
        self.Next = None
        self.Prev = None


class Doubly_Linked_List():
    def __init__(self):
        self.Head = None

    def Insertion_at_Start(self,ele):
        new_Object = Doubly_Creation_Node(ele)
        if (self.Head == None):
            self.Head = new_Object
            return
        else:
            self.Head.Prev = new_Object
            new_Object.Next = self.Head
            self.Head = new_Object

    def Inserton_at_Specific(self,pos,ele):
        new_Object = Doubly_Creation_Node(ele)
        if (pos < 1):
            print("position is greater than <= 1")
        elif (pos == 1 and self.Head == None):
            self.Head = new_Object
            new_Object.Next = self.Head
            self.Head.Prev = new_Object
            return
        else:
            temp = self.Head
            for i in range(pos-1):
                if (temp.Next != None):
                    temp = temp.Next
            if (temp != None):
                new_Object.Next = temp.Next
                temp.Next = new_Object
                
    def Insertion_at_End(self,ele):
        new_Object = Doubly_Creation_Node(ele)
        if (self.Head == None):
            self.Head = new_Object
            new_Object.Next = self.Head
            self.Head.Prev = new_Object
            return
        else:
            temp = self.Head
            while (temp.Next != None):
                temp = temp.Next
            temp.Next = new_Object
            new_Object.Prev = temp.Next
    
    def Search_Node(self,item):
        temp = self.Head
        found = 0
        i = 0
        if (temp != None):
            while (temp != None):
                i += 1
                if (temp.elements == item):
                    found += 1
                    break
                temp = temp.Next
            if (found == 1):
                print(found,"elements are elements" ,i)
            else:
                print(found,'elements are not found',i)
        else:
            print("elements are empty")
    
    def Count_Node(self):
        Count = 0
        temp = self.Head
        while (temp.Next != None):
            Count += 1
            temp = temp.Next
        return Count

    def Deletion_at_Start(self):
        if (self.Head == None):
            self.Head = None
            return
        else:
            First_Node = self.Head
            self.Head = self.Head.Next
            First_Node = None
    def Deletion_at_Specific(self,pos):
        if (pos < 1):
            print("postion is greater than <= 1")
        elif (pos == 1 and self.Head == None):
            First_Node = self.Head
            self.Head = self.Head.Next
            First_Node = None
            return
        else:
            temp = self.Head
            for i in range(pos-1):
                if (temp.Next != None):
                    temp = temp.Next
            if (temp != None):
                Position_Node = temp.Next
                temp.Next = temp.Next.Next
                Position_Node = None
                
    def Deletion_at_End(self):
        if (self.Head == None):
            self.Head = None
            return
        else:
            temp = self.Head
            while (temp.Next.Next != None):
                temp = temp.Next
            End_Node = temp.Next
            temp.Next = temp.Next.Next
            End_Node = None

    def Traversed_Doubly_Linked_List(self):
        temp = self.Head
        if (temp != None):
            while (temp != None):
                print(temp.elements , end ='->')
                temp = temp.Next
            print()
        else:
            print("elements are empty")


if __name__ == "__main__":
    root = Doubly_Linked_List()
    root.Insertion_at_Start(45)
    root.Insertion_at_Start(36)
    root.Insertion_at_Start(18)
    root.Inserton_at_Specific(2,89)
    root.Inserton_at_Specific(1,88)
    root.Inserton_at_Specific(3,87)
    root.Insertion_at_End(90)
    root.Insertion_at_End(91)
    root.Insertion_at_End(92)
    root.Search_Node(89)
    print(root.Count_Node())
    root.Deletion_at_Start()
    root.Deletion_at_Start()
    root.Deletion_at_Specific(2)
    root.Deletion_at_Specific(1)
    root.Deletion_at_Specific(3)
    root.Deletion_at_End()
    root.Deletion_at_End()
    root.Deletion_at_End()
    root.Traversed_Doubly_Linked_List()
# Out:
# 1 elements are elements 5
# 8
# 36->

# %%
class Doubly_Circular_Creation_Node(object):
    def __init__(self,elements):
        self.elements = elements
        self.Next = None
        self.Prev = None


class Doubly_Circular_Linked_List():
    def __init__(self):
        self.Head = None

    def Insertion_at_Start(self,ele):
        new_Object = Doubly_Circular_Creation_Node(ele)
        if (self.Head == None):
            self.Head = new_Object
            new_Object.Next = self.Head
            return
        else:
            temp = self.Head
            while (temp.Next != self.Head):
                temp = temp.Next
            temp.Next = new_Object
            new_Object.Prev = self.Head

    def Traverse_Linked_List(self):
        temp = self.Head
        if (temp != None):
            print("elements are listed...")
            while (temp != None):
                print(temp.elements , end = '->')
                temp = temp.Next
                if (temp == self.Head):
                    break
            print()
        else:
            print("elements are listed...")


if __name__ == "__main__":
    root = Doubly_Circular_Linked_List()
    root.Insertion_at_Start(45)
    root.Insertion_at_Start(36)
    root.Insertion_at_Start(18)
    root.Traverse_Linked_List()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[86], line 43
#      41 root.Insertion_at_Start(45)
#      42 root.Insertion_at_Start(36)
# ---> 43 root.Insertion_at_Start(18)
#      44 root.Traverse_Linked_List()
#
# Cell In[86], line 20, in Doubly_Circular_Linked_List.Insertion_at_Start(self, ele)
#      18 else:
#      19     temp = self.Head
# ---> 20     while (temp.Next != self.Head):
#      21         temp = temp.Next
#      22     temp.Next = new_Object
#
# AttributeError: 'NoneType' object has no attribute 'Next'
